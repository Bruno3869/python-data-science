# %% [markdown]
# # Objets et Classes

# %%
class Car():
    def __init__(self):
        self.color = "Black"
        self.mark = "Audi"
        self.model = "A4"

# %%
audi_car = Car()

# %%
class Team():
    def __init__(self):
        self.name = "Manchester"

# %%
man = Team()

# %%
print(man.name)
# Out:
# Manchester

# %% [markdown]
# ## La méthode d'instance __init__

# %%
class Team():
    def __init__(self, name):
        self.name = name

# %%
madrid = Team("Real Madrid")

# %%
print(madrid.name)
# Out:
# Real Madrid
