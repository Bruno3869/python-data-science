# %% [markdown]
# # Fichiers et boucles

# %% [markdown]
# ## Ouvrir et lire un fichier

# %% [markdown]
# ### Ouverture d'un fichier

# %%
#open()
open("python.txt", "r")
# Out:
# <_io.TextIOWrapper name='python.txt' mode='r' encoding='UTF-8'>

# %%
f = open("python.txt", "r")
print(f)
# Out:
# <_io.TextIOWrapper name='python.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# ### Lecture d'un fichier

# %%
#read()
g = f.read()
print(g)
# Out:
# Je lis mon premier fichier !!!

# %% [markdown]
# ### Training

# %%
f = open("departements_fr.csv", "r", encoding="ISO-8859-1")
print(f)
# Out:
# <_io.TextIOWrapper name='departements_fr.csv' mode='r' encoding='UTF-16'>

# %%
data = f.read()
print(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# <ipython-input-11-55fe8af8d0f5> in <module>
# ----> 1 data = f.read()
#       2 print(data)
#
# /srv/conda/envs/notebook/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# /srv/conda/envs/notebook/lib/python3.7/encodings/utf_16.py in _buffer_decode(self, input, errors, final)
#      65                 self.decoder = codecs.utf_16_be_decode
#      66             elif consumed >= 2:
# ---> 67                 raise UnicodeError("UTF-16 stream does not start with BOM")
#      68             return (output, consumed)
#      69         return self.decoder(input, self.errors, final)
#
# UnicodeError: UTF-16 stream does not start with BOM
