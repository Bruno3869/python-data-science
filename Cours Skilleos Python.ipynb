# %% [markdown]
# # Python Data Science

# %% [markdown]
# ## Récupérer une valeur dans une liste

# %%
years = [2013, 2014, 2015, 2016, 2017]

# %%
print(years)
# Out:
# [2013, 2014, 2015, 2016, 2017]
